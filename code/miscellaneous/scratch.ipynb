# %%
import sys
sys.path.append('..')
import misc, bfgs
from tomo2D import drt as drt

# %%
## sparse
misc.x_visual(n=100, sparse=1)

# %%
## non-sparse, poorly conditioned
misc.x_visual(n=100, sparse=0)

# %%
## sparse
misc.bfgs_resids(n=100, sparse=1, X=False)
# Out:
# CG took 0.003217 sec
# GD took 0.032343 sec
# step size at 0: 0.183447
# step size at 1: 0.236739
# step size at 2: 0.423684
# step size at 3: 0.228211
# step size at 4: 0.346186
# step size at 5: 0.192549
# step size at 6: 0.678913
# step size at 7: 1.096704
# step size at 8: 0.420460
# step size at 9: 0.824079
# step size at 10: 0.880637
# step size at 11: 0.584534
# step size at 12: 0.389113
# step size at 13: 3.046668
# step size at 14: 0.746961
# step size at 15: 0.936090
# step size at 16: 0.456842
# step size at 17: 1.362692
# step size at 18: 1.479190
# step size at 19: 0.655854
# step size at 20: 3.545792
# step size at 21: 1.728138
# step size at 22: 1.308212
# step size at 23: 1.104931
# step size at 24: 2.954596
# step size at 25: 4.702789
# step size at 26: 0.719891
# step size at 27: 0.853592
# step size at 28: 9.092087
# step size at 29: 552.153045
# step size at 30: 1.219417
# step size at 31: 10.315231
# step size at 32: 21.220115
# step size at 33: 13606.925257
# ...

# %%
## non-sparse, poorly conditioned
misc.bfgs_resids(n=100, sparse=0, X=False)
# Out:
# 10**8
# CG took 0.016911 sec
# GD took 0.022379 sec
# step size at 0: 0.000000
# step size at 1: 0.000000
# step size at 2: 0.000000
# step size at 3: 0.000000
# step size at 4: 0.000000
# step size at 5: 0.000000
# step size at 6: 0.000000
# step size at 7: 0.000000
# step size at 8: 0.000000
# step size at 9: 0.000000
# step size at 10: 0.000000
# step size at 11: 0.000000
# step size at 12: 0.000000
# step size at 13: 0.000000
# step size at 14: 0.000000
# step size at 15: 0.000000
# step size at 16: 0.000000
# step size at 17: 0.000000
# step size at 18: 0.000000
# step size at 19: 0.000000
# step size at 20: 0.000000
# step size at 21: 0.000000
# step size at 22: 0.000000
# step size at 23: 0.000000
# step size at 24: 0.000000
# step size at 25: 0.000000
# step size at 26: 0.000000
# step size at 27: 0.000000
# step size at 28: 0.000000
# step size at 29: 0.000000
# step size at 30: 0.000000
# step size at 31: 0.000000
# step size at 32: 0.000000
# step size at 33: 0.000000
# ...

# %%
## sparse n = 1000
misc.bfgs_resids(n=1000, sparse=1, X=False)
# Out:
# CG took 0.148550 sec
# GD took 0.147495 sec
# step size at 0: 0.010882
# step size at 1: 0.035722
# step size at 2: 0.052880
# step size at 3: 0.054428
# step size at 4: 0.061015
# step size at 5: 0.067828
# step size at 6: 0.066273
# step size at 7: 0.073345
# step size at 8: 0.068250
# step size at 9: 0.071714
# step size at 10: 0.074698
# step size at 11: 0.070225
# step size at 12: 0.077461
# step size at 13: 0.072651
# step size at 14: 0.077824
# step size at 15: 0.071677
# step size at 16: 0.077391
# step size at 17: 0.078152
# step size at 18: 0.079522
# step size at 19: 0.076478
# step size at 20: 0.079227
# step size at 21: 0.082488
# step size at 22: 0.086399
# step size at 23: 0.076167
# step size at 24: 0.082220
# step size at 25: 0.076566
# step size at 26: 0.076317
# step size at 27: 0.081260
# step size at 28: 0.086270
# step size at 29: 0.085505
# step size at 30: 0.090008
# step size at 31: 0.080596
# step size at 32: 0.082768
# step size at 33: 0.082766
# ...

# %%
## sparse n = 1000
misc.bfgs_resids(n=1000, sparse=0, X=False)
# Out:
# 10**8
# CG took 0.174670 sec
# GD took 0.359632 sec
# step size at 0: 0.000000
# step size at 1: 0.000000
# step size at 2: 0.000000
# step size at 3: 0.000000
# step size at 4: 0.000000
# step size at 5: 0.000000
# step size at 6: 0.000000
# step size at 7: 0.000000
# step size at 8: 0.000000
# step size at 9: 0.000000
# step size at 10: 0.000000
# step size at 11: 0.000000
# step size at 12: 0.000000
# step size at 13: 0.000000
# step size at 14: 0.000000
# step size at 15: 0.000000
# step size at 16: 0.000000
# step size at 17: 0.000000
# step size at 18: 0.000000
# step size at 19: 0.000000
# step size at 20: 0.000000
# step size at 21: 0.000000
# step size at 22: 0.000000
# step size at 23: 0.000000
# step size at 24: 0.000000
# step size at 25: 0.000000
# step size at 26: 0.000000
# step size at 27: 0.000000
# step size at 28: 0.000000
# step size at 29: 0.000000
# step size at 30: 0.000000
# step size at 31: 0.000000
# step size at 32: 0.000000
# step size at 33: 0.000000
# ...
